# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Load dataset

# %%
df = pd.read_csv('book data.csv')
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors average_rating        isbn    isbn13  \
# 0  J.K. Rowling/Mary GrandPré           4.57   439785960  9.78E+12
# 1  J.K. Rowling/Mary GrandPré           4.49   439358078  9.78E+12
# 2                J.K. Rowling           4.42   439554896  9.78E+12
# 3  J.K. Rowling/Mary GrandPré           4.56  043965548X  9.78E+12
# 4  J.K. Rowling/Mary GrandPré           4.78   439682584  9.78E+12
#
#   language_code   num_pages  ratings_count  text_reviews_count  \
# 0           eng         652        2095690               27591
# 1           eng         870        2153167               29221
# 2           eng         352           6333                 244
# 3           eng         435        2339585               36325
# 4           eng        2690          41428                 164
#
#   publication_date        publisher Unnamed: 12
# 0        9/16/2006  Scholastic Inc.         NaN
# 1       09-01-2004  Scholastic Inc.         NaN
# 2       11-01-2003       Scholastic         NaN
# 3       05-01-2004  Scholastic Inc.         NaN
# 4        9/13/2004       Scholastic         NaN

# %%
df.tail()
# Out:
#        bookID                                             title  \
# 11122   45631  Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                       You Bright and Risen Angels
# 11124   45634                   The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                       Poor People
# 11126   45641                       Las aventuras de Tom Sawyer
#
#                                                  authors average_rating  \
# 11122  William T. Vollmann/Larry McCaffery/Michael He...           4.06
# 11123                                William T. Vollmann           4.08
# 11124                                William T. Vollmann           3.96
# 11125                                William T. Vollmann           3.72
# 11126                                         Mark Twain           3.91
#
#              isbn    isbn13 language_code   num_pages  ratings_count  \
# 11122  1560254416  9.78E+12           eng         512            156
# 11123   140110879  9.78E+12           eng         635            783
# 11124   140131965  9.78E+12           eng         415            820
# 11125    60878827  9.78E+12           eng         434            769
# 11126  8497646983  9.79E+12           spa         272            113
#
#        text_reviews_count publication_date      publisher Unnamed: 12
# 11122                  20       12/21/2004  Da Capo Press         NaN
# 11123                  56       12-01-1988  Penguin Books         NaN
# 11124                  95       08-01-1993  Penguin Books         NaN
# 11125                 139        2/27/2007           Ecco         NaN
# 11126                  12        5/28/2006  Edimat Libros         NaN

# %%
df.drop(['Unnamed: 12'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors average_rating        isbn    isbn13  \
# 0  J.K. Rowling/Mary GrandPré           4.57   439785960  9.78E+12
# 1  J.K. Rowling/Mary GrandPré           4.49   439358078  9.78E+12
# 2                J.K. Rowling           4.42   439554896  9.78E+12
# 3  J.K. Rowling/Mary GrandPré           4.56  043965548X  9.78E+12
# 4  J.K. Rowling/Mary GrandPré           4.78   439682584  9.78E+12
#
#   language_code   num_pages  ratings_count  text_reviews_count  \
# 0           eng         652        2095690               27591
# 1           eng         870        2153167               29221
# 2           eng         352           6333                 244
# 3           eng         435        2339585               36325
# 4           eng        2690          41428                 164
#
#   publication_date        publisher
# 0        9/16/2006  Scholastic Inc.
# 1       09-01-2004  Scholastic Inc.
# 2       11-01-2003       Scholastic
# 3       05-01-2004  Scholastic Inc.
# 4        9/13/2004       Scholastic

# %%
def combine(data):
    features = []
    for i in range(0, df.shape[0]):
        features.append( data['title'][i] + ' ' + data['authors'][i] + ' ' + data['publisher'][i] )
    return features

# %%
df['Imp_Features'] = combine(df)

# %%
df.drop(['isbn', 'isbn13', 'ratings_count', 'text_reviews_count', 'publication_date'], axis=1, inplace=True)

# %%
index_names = df[ (df['language_code'] != 'eng') & (df['language_code'] != 'en-US')].index

df.drop(index_names, inplace=True)

# %%
df.language_code.unique()
# Out:
# array(['eng', 'en-US'], dtype=object)

# %%
df.drop_duplicates(subset='title', keep='first', inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df['bookID_idx'] = np.arange(len(df))

# %%
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors average_rating language_code   num_pages  \
# 0  J.K. Rowling/Mary GrandPré           4.57           eng         652
# 1  J.K. Rowling/Mary GrandPré           4.49           eng         870
# 2                J.K. Rowling           4.42           eng         352
# 3  J.K. Rowling/Mary GrandPré           4.56           eng         435
# 4  J.K. Rowling/Mary GrandPré           4.78           eng        2690
#
#          publisher                                       Imp_Features  \
# 0  Scholastic Inc.  Harry Potter and the Half-Blood Prince (Harry ...
# 1  Scholastic Inc.  Harry Potter and the Order of the Phoenix (Har...
# 2       Scholastic  Harry Potter and the Chamber of Secrets (Harry...
# 3  Scholastic Inc.  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       Scholastic  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#    bookID_idx
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4

# %%
df.tail()
# Out:
#       bookID                                             title  \
# 9605   45630                                 Whores for Gloria
# 9606   45631  Expelled from Eden: A William T. Vollmann Reader
# 9607   45633                       You Bright and Risen Angels
# 9608   45634                   The Ice-Shirt (Seven Dreams #1)
# 9609   45639                                       Poor People
#
#                                                 authors average_rating  \
# 9605                                William T. Vollmann           3.69
# 9606  William T. Vollmann/Larry McCaffery/Michael He...           4.06
# 9607                                William T. Vollmann           4.08
# 9608                                William T. Vollmann           3.96
# 9609                                William T. Vollmann           3.72
#
#      language_code   num_pages      publisher  \
# 9605         en-US         160  Penguin Books
# 9606           eng         512  Da Capo Press
# 9607           eng         635  Penguin Books
# 9608           eng         415  Penguin Books
# 9609           eng         434           Ecco
#
#                                            Imp_Features  bookID_idx
# 9605  Whores for Gloria William T. Vollmann Penguin ...        9605
# 9606  Expelled from Eden: A William T. Vollmann Read...        9606
# 9607  You Bright and Risen Angels William T. Vollman...        9607
# 9608  The Ice-Shirt (Seven Dreams #1) William T. Vol...        9608
# 9609               Poor People William T. Vollmann Ecco        9609

# %%
df.to_csv(r'./book_rec_data.csv', index=False)

# %%
def get_data():
    book_data = pd.read_csv('book_rec_data.csv')
    book_data['title'] = book_data['title'].str.lower()
    
    return book_data

# %%
from sklearn.feature_extraction.text import CountVectorizer as cv
from sklearn.metrics.pairwise import cosine_similarity as cs

# %%
def transform_data(data):
    count_mat = cv().fit_transform(data['Imp_Features'])
    
    cos_sim_mat = cs(count_mat)

    return cos_sim_mat

# %%
def recommender(btitle, data, transform):
    bID = data[data.title == btitle]['bookID_idx'].values[0]
    scores = list(enumerate(transform[bID]))
    
    sorted_scores = sorted(scores, key = lambda x:x[1], reverse=True)
    sorted_scores = sorted_scores[1:]
    
    book_indices = [i[0] for i in sorted_scores]
    book_id = data['bookID'].iloc[book_indices]
    book_title = data['title'].iloc[book_indices]
    
    recommendation_data = pd.DataFrame(columns=['Book_ID', 'Title'])
    
    recommendation_data['Book_ID'] = book_id
    recommendation_data['Title'] = book_title
    
    return recommendation_data

# %%
def results(title):
    title = title.str.lower()
    
    find_title = get_data()
    transf_res = transform_data(find_title)
    
    if title not in find_title['title'].unique():
        return 'book not in Database'
    else:
        recommendation = recommender(title, find_title, transf_res)
        return recommendations.to_dict('records')
